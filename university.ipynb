# %%
library(ggplot2)

# %%
library(caret)
# Out:
# Loading required package: lattice

# %%
data <- read.csv("National Universities Rankings.csv")

# %%
summary(data)
# Out:
#                               Name                 Location        Rank
#  Adelphi University             :  1   New York, NY    :  6   Min.   :  1
#  American University            :  1   Chicago, IL     :  5   1st Qu.: 56
#  Andrews University             :  1   Washington, DC  :  5   Median :111
#  Arizona State University--Tempe:  1   Boston, MA      :  4   Mean   :114
#  Ashland University             :  1   Cambridge, MA   :  3   3rd Qu.:171
#  Auburn University              :  1   Philadelphia, PA:  3   Max.   :220
#  (Other)                        :225   (Other)         :205
# ...

# %%
sapply(data, class)
# Out:
#                 Name             Location                 Rank
#             "factor"             "factor"            "integer"
#          Description     Tuition.and.fees             In.state
#             "factor"             "factor"             "factor"
# Undergrad.Enrollment
#             "factor"

# %%
sapply(data, levels)
# Out:
# $Name
#   [1] "Adelphi University"
#   [2] "American University"
#   [3] "Andrews University"
#   [4] "Arizona State University--Tempe"
#   [5] "Ashland University"
#   [6] "Auburn University"
#   [7] "Azusa Pacific University"
#   [8] "Ball State University"
#   [9] "Baylor University"
#  [10] "Benedictine University"
#  [11] "Binghamton University--SUNY"
#  [12] "Biola University"
#  [13] "Boston College"
#  [14] "Boston University"
#  [15] "Bowling Green State University"
#  [16] "Brandeis University"
#  [17] "Brigham Young University--Provo"
#  [18] "Brown University"
#  [19] "California Institute of Technology"
#  [20] "California State University--Fresno"
#  [21] "California State University--Fullerton"
#  [22] "Carnegie Mellon University"
#  [23] "Case Western Reserve University"
#  [24] "Central Michigan University"
#  [25] "Clarkson University"
#  [26] "Clark University"
#  [27] "Clemson University"
#  [28] "College of William & Mary"
#  [29] "Colorado School of Mines"
# ...

# %%
head(data)
# Out:
#                    Name      Location Rank
# 1  Princeton University Princeton, NJ    1
# 2    Harvard University Cambridge, MA    2
# 3 University of Chicago   Chicago, IL    3
# 4       Yale University New Haven, CT    3
# 5   Columbia University  New York, NY    5
# 6   Stanford University  Stanford, CA    5
# ...

# %%
tail(data)
# Out:
#                                         Name            Location Rank
# 226      University of Massachusetts--Boston          Boston, MA  220
# 227   University of Massachusetts--Dartmouth North Dartmouth, MA  220
# 228        University of Missouri--St. Louis       St. Louis, MO  220
# 229 University of North Carolina--Greensboro      Greensboro, NC  220
# 230       University of Southern Mississippi     Hattiesburg, MS  220
# 231                    Utah State University           Logan, UT  220
# ...

# %%
dim(data)
# Out:
# [1] 231   7

# %%
plot(data$Rank,data$Tuition.and.fees, col = "blue")

# %%
plot(data$Rank, data$In.state, col = "Red")
